# %%
import pandas
import sqlite3
from datetime import date, timedelta

# %%
# Function to reset weekly total
def weekly_reset():
    week_day = date.today().weekday()
    if week_day == 0:
        return 100000
    else:
        return 0

def daily_reset():
    return 13700

# Take the total for the year and than get the days in the year left 
# find the average steps per day needed to reach the yearly number
yearly_total = 5200000
weekly_total = 100000
daily_total = 13700
daily_steps = 5600

# %%
prog_choice = int(input('Welcome to Step Up!\n--------------------\nPlease a choose a number from the following choices:'
'\n\n1.Daily Steps\n2.Weekly Steps\n3.Yearly Steps\n\n'))

if prog_choice == 1:
    remaining_steps = daily_total - daily_steps
    print(f'You have {remaining_steps} steps to go today! Keep it up!')
elif prog_choice == 2:
    remaining_steps = weekly_total - daily_steps
    print(f'You have {remaining_steps} steps to go this week! Keep it going!')
elif prog_choice == 3:
    remaining_steps = yearly_total - daily_steps
    print(f'You have {remaining_steps} steps to go this year! Keep going!')
# Out:
# Welcome to Step Up!
# --------------------
# Please a choose a number from the following choices:
#
# 1.Daily Steps
# 2.Weekly Steps
# 3.Yearly Steps
#
#  3
# You have 5194400 steps to go this year! Keep going!
